# %% [markdown]
# # OMNIA – Demo Inspect (Exploratory Notebook)
#
# This notebook provides a **lightweight exploratory inspection** of OMNIA outputs.
#
# **Purpose**:
# - quick structural sanity checks
# - non-deterministic / exploratory analysis
# - contrast with `OMNIA_REAL_RUN.ipynb`
#
# > This notebook is *not* used for benchmarks or frozen runs.

# %% [markdown]
# ## Environment setup

# %%
import sys
import json
print("Python version:", sys.version)

# %% [markdown]
# ## Load OMNIA (local clone expected)
#
# This notebook assumes the repository has been cloned in the Colab session.

# %%
import os

repo_root = os.getcwd()
print("Working directory:", repo_root)
print("Files:", os.listdir(repo_root)[:10])

# %% [markdown]
# ## Placeholder inspection cell
#
# Use this section to manually inspect OMNIA intermediate artifacts,
# logs, JSON outputs, or diagnostic measures.

# %%
print("OMNIA demo inspect notebook loaded successfully.")
